# %% [markdown]
# # Creating Datasets for "A Doll's House" by Ibsen
#
# ## 1. Isolating spoken word from stage directions

# %%
import sklearn
import csv
import pandas as pd
from collections import Counter
import re
import string
import nltk

# %% [markdown]
# Editing the English code to work with the Bokmål version of the play script.
# **NOTE:** I have not yet finished cleaning the Bokmål version of the play script. Everything in this doc is a skeleton and will be altered as the actual text I plan on using is finalized.

# %%
filein = open('Et_dukkehjem_cleaned.txt', encoding = 'utf-8').read()
#print(filein)

# %%
spoken = re.sub(r'\((.|\n)+?\)', '', filein)
linda_pattern = re.compile(r'^Fru Linde*.', re.MULTILINE)
spoken = re.sub(linda_pattern, 'FruLinde.', spoken)
#print(spoken)
# need to do something with Sagfører Krogstad name
split_text = spoken.split("\n\n")
#print(split_text)

#print(split_text.index("\u200b \u200b\n \u200b\nFØRSTE AKT."))

spoken_text = split_text[7:] # begins at first line of script
#print(spoken_text)

# %% [markdown]
# Cleaning and lowercasing the play script

# %%
doll_cleaned = []
for line in spoken_text:
    cleanedline = line
    for p in string.punctuation:
        cleanedline = cleanedline.replace(p,"").lower()
    doll_cleaned.append(cleanedline.lower()+"\n")
#print(doll_cleaned)

# from nltk.tokenize import word_tokenize
# tokens = word_tokenize(text)
# # remove all tokens that are not alphabetic
# words = [word for word in tokens if word.isalpha()]

# there's some weird punctuation happening in this script (i.e. Torvald--?)

# %% [markdown]
# ## 2. Getting the names and associated lines for each character

# %% [markdown]
# Getting the names of each character that speaks

# %%
name = []

for speech in doll_cleaned:
    character_line = speech.split()
    #print(speech)
    if len(character_line) > 1:
        # splits each speech into words
        #print("hello from the if statement")
        character_name = character_line[0] + " " # grabs first word, which will always be name of character speaking
        name.append(character_name)
        #name += character_name
        
#print(name)
print(len(name))
# Out:
# 1251

# %% [markdown]
# Getting the speech content of each character that speaks, minus their name

# %%
character_speech_list = []
for speech in doll_cleaned:
    split_speech = speech.strip().split()
    if len(split_speech) > 1:
        indexed_speech = split_speech[1:]
        character_speech_list.append(indexed_speech)
#         character_line = speech.split()
#         #character_speech = character_line[1:]
        #character_speech_list+=speech


print(character_speech_list)
#print(len(character_speech_list))
#for line in character_speech_list:
    #print(line)
# Out:
# [['gem', 'juletræet', 'godt', 'helene', 'børnene', 'må', 'endelig', 'ikke', 'få', 'se', 'det', 'før', 'iaften', 'når', 'det', 'er', 'pyn', 'tet', 'hvormeget', '–'], ['femti', 'øre'], ['der', 'er', 'en', 'krone', 'nej', 'behold', 'det', 'hele'], ['jo', 'han', 'er', 'hjemme'], ['er', 'det', 'lærkefuglen', 'som', 'kvidrer', 'derude'], ['ja', 'det', 'er', 'det'], ['er', 'det', 'ekornet', 'som', 'rumsterer', 'der'], ['ja'], ['når', 'kom', 'ekornet', 'hjem'], ['nu', 'netop', 'kom', 'herud', 'torvald', 'så', 'skal', 'du', 'få', 'se', 'hvad', 'jeg', 'har', 'købt'], ['ikke', 'forstyr', 'købt', 'siger', 'du', 'alt', 'det', 'der', 'har', 'nu', 'lille', 'spillefuglen', 'været', 'ude', 'og', 'sat', 'penge', 'over', 'styr', 'igen'], ['ja', 'men', 'torvald', 'iår', 'må', 'vi', 'dog', 'virkelig', 'slå', 'os', 'lidt', 'løs', 'det', 'er', 'jo', 'den', 'første', 'jul', 'da', 'vi', 'ikke', 'behøver', 'at', 'spare'], ['å', 'ved', 'du', 'hvad', 'ødsle', 'kan', 'vi', 'ikke'], ['jo', 'torvald', 'lidt', 'kan', 'vi', 'nok', 'ødsle', 'nu', 'ikke', 'sandt', 'bare', 'en', 'liden', 'bitte', 'smule', 'nu', 'får', 'du', 'jo', 'en', 'stor', 'gage', 'og', 'kommer', 'til', 'at', 'tjene', 'mange', 'mange', 'penge'], ['ja', 'fra', 'nytår', 'af', 'men', 'så', 'går', 'der', 'et', 'helt', 'fjerdingår', 'før', 'gagen', 'forfalder'], ['pyt', 'vi', 'kan', 'jo', 'låne', 'så', 'længe'], ['nora', 'er', 'nu', 'letsindigheden', 'ude', 'og', 'går', 'igen', 'sæt', 'nu', 'jeg', 'lånte', 'tusend', 'kroner', 'idag', 'og', 'du', 'satte', 'dem', 'overstyr', 'i', 'juleugen', 'og', 'jeg', 'så', 'nytårsaften', 'fik', 'en', 'tagsten', 'i', 'hodet', 'og', 'lå', 'der', '–'], ['å', 'fy', 'tal', 'ikke', 'så', 'stygt'], ['jo', 'sæt', 'nu', 'at', 'sligt', 'hændte', '–', 'hvad', 'så'], ['hvis', 'der', 'hændte', 'noget', 'så', 'fælt', 'så', 'kunde', 'det', 'være', 'ganske', 'det', 'samme', 'enten', 'jeg', 'havde', 'gæld', 'eller', 'ikke'], ['nå', 'men', 'de', 'folk', 'jeg', 'havde', 'lånt', 'af'], ['de', 'hvem', 'bryr', 'sig', 'om', 'dem', 'det', 'er', 'jo', 'fremmede'], ['nora', 'nora', 'du', 'est', 'en', 'kvinde', 'nej', 'men', 'al', 'vorligt', 'nora', 'du', 'ved', 'hvad', 'jeg', 'tænker', 'i', 'det', 'stykke', 'ingen', 'gæld', 'aldrig', 'låne', 'der', 'kommer', 'noget', 'ufrit', 'og', 'altså', 'også', 'noget', 'uskønt', 'over', 'det', 'hjem', 'som', 'grundes', 'på', 'lån', 'og', 'gæld', 'nu', 'har', 'vi', 'to', 'holdt', 'tappert', 'ud', 'lige', 'til', 'idag', 'og', 'det', 'vil', 'vi', 'også', 'gøre', 'den', 'korte', 'tid', 'det', 'endnu', 'behøves'], ['ja', 'ja', 'som', 'du', 'vil', 'torvald'], ['så', 'så', 'nu', 'skal', 'ikke', 'lille', 'sanglærken', 'hænge', 'med', 'vingerne', 'hvad', 'står', 'ekornen', 'der', 'og', 'sur', 'muler', 'nora', 'hvad', 'tror', 'du', 'jeg', 'har', 'her'], ['penge'], ['se', 'der', 'herregud', 'jeg', 'ved', 'jo', 'nok', 'at', 'der', 'går', 'en', 'hel', 'del', 'til', 'i', 'et', 'hus', 'i', 'juletiden'], ['ti', '–', 'tyve', '–', 'tredive', '–', 'firti', 'å', 'tak', 'tak', 'torvald', 'nu', 'hjælper', 'jeg', 'mig', 'langt'], ['ja', 'det', 'må', 'du', 'sandelig', 'gøre'], ['ja', 'ja', 'det', 'skal', 'jeg', 'nok', 'men', 'kom', 'her', 'så', 'skal', 'jeg', 'vise', 'dig', 'alt', 'hvad', 'jeg', 'har', 'købt', 'og', 'så', 'billigt', 'se', 'her', 'er', 'nye', 'klæder', 'til', 'ivar', '–', 'og', 'så', 'en', 'sabel', 'her', 'er', 'en', 'hest', 'og', 'en', 'trompet', 'til', 'bob', 'og', 'her', 'er', 'dukke', 'og', 'dukkeseng', 'til', 'emmy', 'det', 'er', 'nu', 'så', 'simpelt', 'men', 'hun', 'river', 'det', 'jo', 'snart', 'istykker', 'alligevel', 'og', 'her', 'har', 'jeg', 'kjoletøjer', 'og', 'tørklæder', 'til', 'pigerne', 'gamle', 'annemarie', 'skulde', 'nu', 'havt', 'meget', 'mere'], ['og', 'hvad', 'er', 'der', 'i', 'den', 'pakke', 'der'], ['nej', 'torvald', 'det', 'får', 'du', 'ikke', 'se', 'før', 'iaften'], ['nå', 'så', 'men', 'sig', 'mig', 'nu', 'du', 'lille', 'ødeland', 'hvad', 'har', 'du', 'nu', 'tænkt', 'på', 'til', 'dig', 'selv'], ['å', 'pyt', 'til', 'mig', 'jeg', 'br ...

# %% [markdown]
# Writing out to a .csv file

# %%
#doit = [[x[0], x[1].replace('\n', '')] for x in zip(name, character_speech_list)]

# %% [markdown]
# headers = ['character_name', 'character_speech']
#
# with open('characters_and_speeches-Bokmal.csv', 'w', newline='', encoding = 'utf-8') as outfile:
#     csvout = csv.writer(outfile)
#     csvout.writerow(headers)
#     for r in doit:
#         csvout.writerow(r)

# %%
headers = ['character_name', 'character_speech']

with open('characters_and_speeches-Bokmal.csv', 'w', newline='', encoding='utf-8') as outfile:
    csvout = csv.writer(outfile)
    csvout.writerow(headers)
    csvout.writerows(zip(name, character_speech_list))

# %%
language_dataset = pd.read_csv("characters_and_speeches-Bokmal.csv")
language_dataset.head()
# Out:
#   character_name                                   character_speech
# 0          nora   ['gem', 'juletræet', 'godt', 'helene', 'børnen...
# 1       bybudet                                    ['femti', 'øre']
# 2          nora   ['der', 'er', 'en', 'krone', 'nej', 'behold', ...
# 3          nora                       ['jo', 'han', 'er', 'hjemme']
# 4        helmer   ['er', 'det', 'lærkefuglen', 'som', 'kvidrer',...
